# %%
import pandas as pd

import os

import geopandas as gpd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
sns.set()
sns.set_theme(style='ticks')
sns.set_palette("muted")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rgarcia\\Documents\\Code'

# %%
os.chdir('C:\\Users\\rgarcia\\Documents\\Data')

# %%
df = pd.read_csv('candidatos_presidente_por_municipio_separado.csv')

# %%
df
# Out:
#      ESTADO       MUNICíPIO  LULA VOTOS  LULA VOTOS PERCENTUAL  \
# 0        AC      Acrelândia        1516                  21.30
# 1        AC    Assis Brasil        2003                  41.12
# 2        AC       Brasiléia        4171                  29.50
# 3        AC          Bujari        2130                  29.33
# 4        AC        Capixaba        1630                  27.12
# ...     ...             ...         ...                    ...
# 5565     TO  Tocantinópolis        8328                  66.00
# 5566     TO        Tupirama         881                  60.18
# 5567     TO      Tupiratins         898                  64.84
# 5568     TO    Wanderlândia        3178                  60.01
# 5569     TO         Xambioá        3150                  48.57
#
#       BOLSONARO VOTOS  BOLSONARO PERCENTUAL  CIRO VOTOS  \
# 0                5238                 73.59         117
# 1                2694                 55.31          44
# 2                9143                 64.67         249
# 3                4505                 62.03         197
# 4                3944                 65.61         120
# ...               ...                   ...         ...
# 5565             3745                 29.68         235
# 5566              517                 35.31          25
# 5567              405                 29.24          30
# 5568             1883                 35.56          90
# 5569             3068                 47.30         105
#
#       CIRO VOTOS PERCENTUAL  TEBET VOTOS  TEBET VOTOS PERCENTUAL  \
# 0                      1.64          192                    2.70
# 1                      0.90          109                    2.24
# 2                      1.76          496                    3.51
# 3                      2.71          356                    4.90
# 4                      2.00          264                    4.39
# ...                     ...          ...                     ...
# 5565                   1.86          255                    2.02
# 5566                   1.71           35                    2.39
# 5567                   2.17           45                    3.25
# 5568                   1.70          123                    2.32
# 5569                   1.62          138                    2.13
#
#       OUTROS VOTOS  OUTROS VOTOS PERCENTUAL  ABSTENÇÕES  \
# 0                0                     0.00        2228
# 1                0                     0.00        1371
# 2                1                     0.01        3658
# 3                0                     0.00        2415
# 4                0                     0.00        1670
# ...            ...                      ...         ...
# 5565             0                     0.00        2660
# 5566             0                     0.00         346
# 5567             0                     0.00         412
# 5568             1                     0.02        1352
# 5569             0                     0.00        1626
#
#       ABSTENÇÕES PERCENTUAL  VOTOS BRANCOS  VOTOS BRANCOS PERCENTUAL  \
# 0                     23.40             45                      0.62
# 1                     21.46             22                      0.44
# 2                     20.10            116                      0.79
# 3                     24.28             70                      0.93
# 4                     21.31             36                      0.58
# ...                     ...            ...                       ...
# 5565                  16.94             80                      0.61
# 5566                  18.35             14                      0.91
# 5567                  22.39              9                      0.63
# 5568                  19.61             40                      0.72
# 5569                  19.52             45                      0.67
#
#       VOTOS NULOS  VOTOS NULOS PERCENTUAL
# 0             130                    1.78
# 1             126                    2.51
# 2             283                    1.95
# 3             199                    2.64
# 4             119                    1.93
# ...           ...                     ...
# 5565          348                    2.67
# 5566           62                    4.03
# 5567           34                    2.38
# 5568          205                    3.70
# 5569          171                    2.55
#
# [5570 rows x 18 columns]

# %%
df['Lulometro'] = (df['LULA VOTOS']/df['BOLSONARO VOTOS']).round(2)
# Out:
# 0       0.29
# 1       0.74
# 2       0.46
# 3       0.47
# 4       0.41
#         ...
# 5565    2.22
# 5566    1.70
# 5567    2.22
# 5568    1.69
# 5569    1.03
# Length: 5570, dtype: float64
