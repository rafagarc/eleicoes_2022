# %%
import os

# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
os.chdir('C:\\Users\\rgarcia\\Documents\\Data'); os.listdir()
# Out:
# ['abstencoes_sp.png',
#  'Assassinatos 2021.pdf',
#  'bands.csv',
#  'Biomas',
#  'brasil_coverage_2021.tif',
#  'brasil_coverage_2021.tif.aux.xml',
#  'brazil-states.geojson',
#  'brazil-states_lo_res.json',
#  'brazil_forests.pgw',
#  'BR_Municipios_2021_low_res.json',
#  'BR_Municipios_2021_mid_res.json',
#  'BR_Municipios_2021_very_low_res.json',
#  'candidato_redes_total.csv',
#  'cargo.csv',
#  'consulta_cand_2018_BRASIL.csv',
#  'consulta_cand_2022_BRASIL.csv',
#  'consulta_cand_2022_BRASIL_08_19.csv',
#  'consulta_cand_2022_BRASIL_OLD.csv',
#  'consulta_cand_2022_BRASIL_VEI.csv',
#  'Códigos_Classes_Mapbiomas_Coleção_7.pdf',
#  'dep_est_partido.csv',
#  'dep_est_uf.csv',
#  'dep_fed_partido.csv',
#  'dep_fed_uf.csv',
#  'Desmate_minera.csv',
#  'Desmate_mineracao.csv',
#  'detalhe_votacao_munzona_2018_BRASIL.csv',
#  'forests_brazil.pgw',
#  'forest_colormap.clr',
#  'forest_only.clr',
#  'geojs-100-mun.geojson',
#  'Global_Witness_info.csv',
#  'GW_2021.csv',
# ...

# %%
mun = gpd.read_file('BR_Municipios_2021_very_low_res.json')

# %%
mun
# Out:
#        CD_MUN                 NM_MUN SIGLA  AREA_KM2  \
# 0     1100015  Alta Floresta D'Oeste    RO  7067.127
# 1     1100023              Ariquemes    RO  4426.571
# 2     1100031                 Cabixi    RO  1314.352
# 3     1100049                 Cacoal    RO  3793.000
# 4     1100056             Cerejeiras    RO  2783.300
# ...       ...                    ...   ...       ...
# 5567  5222005             Vianópolis    GO   954.115
# 5568  5222054         Vicentinópolis    GO   733.794
# 5569  5222203               Vila Boa    GO  1052.593
# 5570  5222302          Vila Propício    GO  2181.593
# 5571  5300108               Brasília    DF  5760.784
#
#                                                geometry
# 0     POLYGON ((-62.05044 -11.86735, -62.08701 -11.8...
# 1     POLYGON ((-62.42262 -9.80462, -62.43581 -9.780...
# 2     POLYGON ((-60.70931 -13.69300, -60.68604 -13.6...
# 3     POLYGON ((-61.21172 -11.52910, -61.19011 -11.5...
# ...

# %%
mun.query('SIGLA == "RJ"').plot(figsize=(14,14), column='AREA_KM2', edgecolor="#666666", linewidth=0.5, cmap='magma_r', legend=True)
# Out:
# <AxesSubplot:>
