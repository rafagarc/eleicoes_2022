# %%
import os

# %%
os.chdir(r'C:\Users\rgarcia\Documents\Data\results')

# %%
os.listdir()
# Out:
# ['ccont_1t_SP_011020221232.csv',
#  'CESP_1t_SP_011020221232.zip.sha512',
#  'cmrj_1t_SP_011020221232.csv',
#  'csec_1t_SP_011020221232.csv',
#  'leiame-corresp-esperada-contingencia.pdf',
#  'leiame-corresp-esperada-MRJ.pdf',
#  'leiame-corresp-esperada-secao.pdf']

# %%
import pandas as pd

# %%
df = pd.read_csv('ccont_1t_SP_011020221232.csv', sep=';', encoding='ISO-8859-1', decimal=',', low_memory=False, thousands='.')

# %%
df.sample(n=10)
# Out:
#        DT_GERACAO HH_GERACAO  CD_PLEITO SG_UF  CD_MUNICIPIO      NM_MUNICIPIO  \
# 6827   01/10/2022   12:32:11        406    SP         69450         RANCHARIA
# 7752   01/10/2022   12:32:11        406    SP         70718            SANTOS
# 11318  01/10/2022   12:32:11        406    SP         71072         SÃO PAULO
# 12367  01/10/2022   12:32:11        406    SP         71072         SÃO PAULO
# 4999   01/10/2022   12:32:11        406    SP         66818           MARÍLIA
# 5434   01/10/2022   12:32:11        406    SP         67156        MOGI GUAÇU
# 197    01/10/2022   12:32:11        406    SP         61417         ANDRADINA
# 7926   01/10/2022   12:32:11        406    SP         71331       SERRA NEGRA
# 4473   01/10/2022   12:32:11        406    SP         66150    JOSÉ BONIFÁCIO
# 4678   01/10/2022   12:32:11        406    SP         66370  LENÇÓIS PAULISTA
#
#        NR_ZONA  NR_URNA_ESPERADA    CD_CARGA_URNA_ESPERADA  \
# ...
